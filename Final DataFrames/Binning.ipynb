# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_movies = pd.read_excel('2013-2017 Box Office Data2.xlsx', sheet_name=0, header=0, skiprows=None, skip_footer=0, index_col=None, names=None, usecols=None, parse_dates=False, date_parser=None, na_values=None, thousands=None, convert_float=True, converters=None, dtype=None, true_values=None, false_values=None, engine=None, squeeze=False)
df_movies

#we noted that the year was wrong in the "Open" and "Close" column, but since we are using only the month and the day we were not concerned. the correct year is in the "Year" column.
# Out:
#     Rank                                Movie Title   Studio  Total Gross  \
# 0      1            The Hunger Games: Catching Fire      LGF    424668047
# 1      2                                 Iron Man 3       BV    409013994
# 2      3                                     Frozen       BV    400738009
# 3      4                            Despicable Me 2     Uni.    368061265
# 4      5                               Man of Steel       WB    291045518
# 5      6                                    Gravity       WB    274092705
# 6      7                        Monsters University       BV    268492764
# 7      8        The Hobbit: The Desolation of Smaug  WB (NL)    258366855
# 8      9                           Fast & Furious 6     Uni.    238679850
# 9     10                  Oz The Great and Powerful       BV    234911825
# 10     1                            American Sniper       WB    350126372
# 11     2      The Hunger Games: Mockingjay - Part 1      LGF    337135885
# ...

# %%
df_movies = df_movies[['Movie Title','Open','Close']]
df_movies.head()
# Out:
#                        Movie Title       Open                Close
# 0  The Hunger Games: Catching Fire 2018-11-22  2018-04-03 00:00:00
# 1                       Iron Man 3 2018-05-03  2018-09-12 00:00:00
# 2                           Frozen 2018-11-22  2018-07-17 00:00:00
# 3                  Despicable Me 2 2018-07-03  2018-01-16 00:00:00
# 4                     Man of Steel 2018-06-14  2018-09-19 00:00:00

# %%
df_movies.dtypes
# Out:
# Movie Title            object
# Open           datetime64[ns]
# Close                  object
# dtype: object

# %%
df_movies['Open']=pd.to_datetime(df_movies.Open)
df_movies.head()
# Out:
# C:\Users\gkchan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Movie Title       Open                Close
# 0  The Hunger Games: Catching Fire 2018-11-22  2018-04-03 00:00:00
# 1                       Iron Man 3 2018-05-03  2018-09-12 00:00:00
# 2                           Frozen 2018-11-22  2018-07-17 00:00:00
# 3                  Despicable Me 2 2018-07-03  2018-01-16 00:00:00
# 4                     Man of Steel 2018-06-14  2018-09-19 00:00:00

# %%
df_movies.dtypes
# Out:
# Movie Title            object
# Open           datetime64[ns]
# Close                  object
# dtype: object

# %%
df_movies['Month'] = df_movies.Open.dt.month
df_movies.head()
# Out:
# C:\Users\gkchan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Movie Title       Open                Close  Month
# 0  The Hunger Games: Catching Fire 2018-11-22  2018-04-03 00:00:00     11
# 1                       Iron Man 3 2018-05-03  2018-09-12 00:00:00      5
# 2                           Frozen 2018-11-22  2018-07-17 00:00:00     11
# 3                  Despicable Me 2 2018-07-03  2018-01-16 00:00:00      7
# 4                     Man of Steel 2018-06-14  2018-09-19 00:00:00      6

# %%
#create bins
bins = [0,3,6,9,12]

group_names = ['Winter','Spring','Summer','Fall']

# %%
df_movies['Season'] = pd.cut(df_movies['Month'],bins, labels=group_names)
df_movies.head()
# Out:
# C:\Users\gkchan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Movie Title       Open                Close  Month  \
# 0  The Hunger Games: Catching Fire 2018-11-22  2018-04-03 00:00:00     11
# 1                       Iron Man 3 2018-05-03  2018-09-12 00:00:00      5
# 2                           Frozen 2018-11-22  2018-07-17 00:00:00     11
# 3                  Despicable Me 2 2018-07-03  2018-01-16 00:00:00      7
# 4                     Man of Steel 2018-06-14  2018-09-19 00:00:00      6
#
#    Season
# 0    Fall
# 1  Spring
# 2    Fall
# 3  Summer
# 4  Spring

# %%
df_movies = df_movies[['Movie Title','Month','Season']]
df_movies
# Out:
#                                   Movie Title  Month  Season
# 0             The Hunger Games: Catching Fire     11    Fall
# 1                                  Iron Man 3      5  Spring
# 2                                      Frozen     11    Fall
# 3                             Despicable Me 2      7  Summer
# 4                                Man of Steel      6  Spring
# 5                                     Gravity     10    Fall
# 6                         Monsters University      6  Spring
# 7         The Hobbit: The Desolation of Smaug     12    Fall
# 8                            Fast & Furious 6      5  Spring
# 9                   Oz The Great and Powerful      3  Winter
# 10                            American Sniper     12    Fall
# 11      The Hunger Games: Mockingjay - Part 1     11    Fall
# 12                    Guardians of the Galaxy      8  Summer
# 13        Captain America: The Winter Soldier      4  Spring
# ...

# %%
df_movies.to_csv('season.csv', encoding = 'utf-8')

# %%
group_month = df_movies('Month')

# %%
Months = ["January", "February", "March", "April", "May", "June", "July", "August","September","October","November","December"]
Movies = df_movies['Month']

x_axis = np.arange(len(Months))

plt.bar(x_axis, Movies, color="seagreen", align = "edge")

tick_locations = [value+0.4 for value in x_axis]
plt.xticks(tick_locations, Months)

plt.title("Members per Gym")
plt.xlabel("Gyms")
plt.ylabel("Members")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-18327a60b5e9> in <module>()
#       4 x_axis = np.arange(len(Months))
#       5
# ----> 6 plt.bar(x_axis, Movies, color="seagreen", align = "edge")
#       7
#       8 tick_locations = [value+0.4 for value in x_axis]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2646                       mplDeprecation)
#    2647     try:
# -> 2648         ret = ax.bar(*args, **kwargs)
#    2649     finally:
#    2650         ax._hold = washold
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
# ...
