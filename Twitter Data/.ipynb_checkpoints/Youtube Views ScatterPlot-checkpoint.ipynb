# %%
import numpy as npy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('movie.csv')
movies
# Out:
#                                   Movie Title  \
# 0             The Hunger Games: Catching Fire
# 1                                  Iron Man 3
# 2                                      Frozen
# 3                             Despicable Me 2
# 4                                Man of Steel
# 5                                     Gravity
# 6                         Monsters University
# 7         The Hobbit: The Desolation of Smaug
# 8                            Fast & Furious 6
# 9                   Oz The Great and Powerful
# 10                            American Sniper
# 11      The Hunger Games: Mockingjay - Part 1
# 12                    Guardians of the Galaxy
# 13        Captain America: The Winter Soldier
# 14                             The LEGO Movie
# 15  The Hobbit: The Battle of the Five Armies
# 16            Transformers: Age of Extinction
# 17                                 Maleficent
# 18                 X-Men: Days of Future Past
# ...

# %%
movies.head()
# Out:
#                        Movie Title               Movie Title (loop)  Year  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire  2013
# 1                       Iron Man 3                       Iron Man 3  2013
# 2                           Frozen                           Frozen  2013
# 3                  Despicable Me 2                  Despicable Me 2  2013
# 4                     Man of Steel                     Man of Steel  2013
#
#   Studio  Total Gross Theaters    Opening    Open   Close  Rated  \
# 0    LGF    424668047    4,163  158074286  22-Nov   3-Apr  PG-13
# 1     BV    409013994    4,253  174144585   3-May  12-Sep  PG-13
# 2     BV    400738009    3,742     243390  22-Nov  17-Jul     PG
# 3   Uni.    368061265    4,003   83517315   3-Jul  16-Jan     PG
# 4     WB    291045518    4,207  116619362  14-Jun  19-Sep  PG-13
#
#        ...        Metacritic IMDB Rating      Production Studio  Month  \
# ...

# %%
movies.columns
# Out:
# Index(['Movie Title', 'Movie Title (loop)', 'Year', 'Studio', 'Total Gross',
#        'Theaters', 'Opening', 'Open', 'Close', 'Rated', 'Runtime (Minutes)',
#        'Director', 'Tweets', 'Followers', 'Following', 'Favorites Count',
#        'Actor 1', 'Actor 2', 'Rotten Tomatoes (%)', 'Metacritic',
#        'IMDB Rating', 'Production Studio', 'Month', 'Season', 'View Count',
#        'Video Title', 'Like Count', 'Dislike Count', 'Comment Count'],
#       dtype='object')

# %%
# Create a scatter plot which compares MPG to horsepower iwth the size being model year
movies.plot(kind="scatter", x="View Count", y="Total Gross", s=(movies["Like Count"]/1000), grid=True, figsize=(20,10),
              title="View Count Vs. Total Gross Revenue")
plt.show()
