# %%
import numpy as npy
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
movies = pd.read_csv('movie.csv')
movies
# Out:
#                                   Movie Title  \
# 0             The Hunger Games: Catching Fire
# 1                                  Iron Man 3
# 2                                      Frozen
# 3                             Despicable Me 2
# 4                                Man of Steel
# 5                                     Gravity
# 6                         Monsters University
# 7         The Hobbit: The Desolation of Smaug
# 8                            Fast & Furious 6
# 9                   Oz The Great and Powerful
# 10                            American Sniper
# 11      The Hunger Games: Mockingjay - Part 1
# 12                    Guardians of the Galaxy
# 13        Captain America: The Winter Soldier
# 14                             The LEGO Movie
# 15  The Hobbit: The Battle of the Five Armies
# 16            Transformers: Age of Extinction
# 17                                 Maleficent
# 18                 X-Men: Days of Future Past
# ...

# %%
movies1 = movies[['Movie Title', 'Total Gross', 'Followers']]
movies1
# Out:
#                                   Movie Title  Total Gross  Followers
# 0             The Hunger Games: Catching Fire    424668047    42473.0
# 1                                  Iron Man 3    409013994    24608.0
# 2                                      Frozen    400738009        NaN
# 3                             Despicable Me 2    368061265        NaN
# 4                                Man of Steel    291045518   680710.0
# 5                                     Gravity    274092705        NaN
# 6                         Monsters University    268492764     8111.0
# 7         The Hobbit: The Desolation of Smaug    258366855        NaN
# 8                            Fast & Furious 6    238679850    79846.0
# 9                   Oz The Great and Powerful    234911825        NaN
# 10                            American Sniper    350126372        NaN
# 11      The Hunger Games: Mockingjay - Part 1    337135885    42473.0
# ...

# %%
movies.columns
# Out:
# Index(['Movie Title', 'Movie Title (loop)', 'Year', 'Studio', 'Total Gross',
#        'Theaters', 'Opening', 'Open', 'Close', 'Rated', 'Runtime (Minutes)',
#        'Director', 'Tweets', 'Followers', 'Following', 'Favorites Count',
#        'Actor 1', 'Actor 2', 'Rotten Tomatoes (%)', 'Metacritic',
#        'IMDB Rating', 'Production Studio', 'Month', 'Season', 'View Count',
#        'Video Title', 'Like Count', 'Dislike Count', 'Comment Count'],
#       dtype='object')

# %%
from operator import itemgetter
import numpy as np
from collections import Counter

movies2 = movies[['Movie Title', 'Followers']]
a = np.array(movies2)      
movies3 = np.sort(a, order= 'Followers') 
movies3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-9733d8a9dc0b> in <module>()
#       5 movies2 = movies[['Movie Title', 'Followers']]
#       6 a = np.array(movies2)
# ----> 7 movies3 = np.sort(a, order= 'Followers')
#       8 movies3
#       9
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sort(a, axis, kind, order)
#     845     else:
#     846         a = asanyarray(a).copy(order="K")
# --> 847     a.sort(axis=axis, kind=kind, order=order)
#     848     return a
#     849
#
# ValueError: Cannot specify order when the array has no fields.

# %%
a
# Out:
# array([['The Hunger Games: Catching Fire', 42473.0],
#        ['Iron Man 3', 24608.0],
#        ['Frozen', nan],
#        ['Despicable Me 2', nan],
#        ['Man of Steel', 680710.0],
#        ['Gravity', nan],
#        ['Monsters University', 8111.0],
#        ['The Hobbit: The Desolation of Smaug', nan],
#        ['Fast & Furious 6', 79846.0],
#        ['Oz The Great and Powerful', nan],
#        ['American Sniper', nan],
#        ['The Hunger Games: Mockingjay - Part 1', 42473.0],
#        ['Guardians of the Galaxy', 424925.0],
#        ['Captain America: The Winter Soldier', nan],
#        ['The LEGO Movie', nan],
#        ['The Hobbit: The Battle of the Five Armies', nan],
#        ['Transformers: Age of Extinction', 92689.0],
#        ['Maleficent', nan],
#        ['X-Men: Days of Future Past', nan],
#        ['Big Hero 6', nan],
#        ['Star Wars: The Force Awakens', nan],
#        ['Jurassic World', 60054.0],
#        ['Avengers: Age of Ultron', 226532.0],
# ...

# %%
# Create a scatter plot which compares Total Gross Revenue Per Movie with the Youtube Trailer Views the size being likes


movies.plot(kind="scatter", x="Followers", y="Total Gross", s=(movies["Tweets"]/10), grid=True, figsize=(20,10),
              alpha = 0.7, title="Twitter Followers Vs. Total Gross Revenue")

axes = plt.gca()

plt.show()

# %%
# Create a scatter plot which compares Total Gross Revenue Per Movie with the Youtube Trailer Views the size being likes


movies.plot(kind="scatter", x="View Count", y="Total Gross", s=(movies["Like Count"]/1000), grid=True, figsize=(20,10),
              alpha = 0.5, title="View Count Vs. Total Gross Revenue")

axes = plt.gca()
axes.set_ylim([1800000,824668047])
axes.set_ylim([0,1024668047])
plt.show()

# %%
## Detecting Outliers in Movie Revenue v.s Rotten Tomatoes Rating

movie_outlier = movie_data.loc[movie_data[“Total_Gross”] > 700000000,[“Rotten_Tomatoes_(%)“, “Total_Gross”, “Movie_Title”] ]

plt.scatter(movie_outlier[“Rotten_Tomatoes_(%)“], movie_outlier[“Total_Gross”],

           c=“red”, label= “Outlier: ” + movie_outlier[“Movie_Title”].values )

# %%
from pylab import *
from scipy import *

# %%
x=[]
y=[]
x1 = []
color=[]
size=[]

# %%
movies.plot(kind="scatter", x="Followers", y="Total Gross", s=(movies["Favorites Count"]/10), grid=True, figsize=(20,10),
              title="Twitter Followers Vs. Total Gross Revenue")

axes = plt.gca()

plt.show()
# Out:
#   File "<ipython-input-92-eace4eb799fd>", line 2
#     x.append(row."Followers")
#                            ^
# SyntaxError: invalid syntax
