# %%
import json
import requests
import pandas as pd
from pprint import pprint

# %%
df_movies = pd.read_excel('2013-2017 Box Office Data.xlsx', sheet_name=0, header=0, skiprows=None, skip_footer=0, index_col=None, names=None, usecols=None, parse_dates=False, date_parser=None, na_values=None, thousands=None, convert_float=True, converters=None, dtype=None, true_values=None, false_values=None, engine=None, squeeze=False)
df_movies
# Out:
#     Rank                                Movie Title   Studio  Total Gross  \
# 0      1            The Hunger Games: Catching Fire      LGF    424668047
# 1      2                                 Iron Man 3       BV    409013994
# 2      3                                     Frozen       BV    400738009
# 3      4                            Despicable Me 2     Uni.    368061265
# 4      5                               Man of Steel       WB    291045518
# 5      6                                    Gravity       WB    274092705
# 6      7                        Monsters University       BV    268492764
# 7      8        The Hobbit: The Desolation of Smaug  WB (NL)    258366855
# 8      9                           Fast & Furious 6     Uni.    238679850
# 9     10                  Oz The Great and Powerful       BV    234911825
# 10     1                            American Sniper       WB    350126372
# 11     2      The Hunger Games: Mockingjay - Part 1      LGF    337135885
# ...

# %%
key = "AIzaSyDJjB7jRXjdsPFeMeOJOm62lf_yk27GmY0"

# %%
for index, row in df_movies.iterrows():
    base_url_search = "https://www.googleapis.com/youtube/v3/search?part=snippet&q=movie%2Btrailer%2B{}&key={}"
    q = row['Movie Title']
    response = requests.get(base_url_search.format(q,key)).json()
    df_movies.set_value(index,"Video ID", response['items'][0]['id']['videoId'])

df_movies
# Out:
# C:\Users\gkchan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
#     Rank                                Movie Title   Studio  Total Gross  \
# 0      1            The Hunger Games: Catching Fire      LGF    424668047
# 1      2                                 Iron Man 3       BV    409013994
# 2      3                                     Frozen       BV    400738009
# 3      4                            Despicable Me 2     Uni.    368061265
# 4      5                               Man of Steel       WB    291045518
# 5      6                                    Gravity       WB    274092705
# 6      7                        Monsters University       BV    268492764
# 7      8        The Hobbit: The Desolation of Smaug  WB (NL)    258366855
# 8      9                           Fast & Furious 6     Uni.    238679850
# ...

# %%
video_id= df_movies['Video ID']
print(video_id)
# Out:
# 0     EAzGXqJSDJ8
# 1     Ke1Y3P9D0Bc
# 2     TbQm5doF_Uc
# 3     koNSa_6Fd1U
# 4     T6DJcgm3wNY
# 5     OiTiKOy59o4
# 6     QxrQ6BaijAY
# 7     OPVWy1tFXuc
# 8     Buf4_Crt27c
# 9     DylgNj4YQVc
# 10    99k3u9ay1gs
# 11    3PkkHsuMrho
# 12    d96cjJhvlMA
# 13    7SlILk2WMTI
# 14    fZ_JOBCLF-I
# 15    iVAgTiBrrDA
# 16    dYDGqmxMZFI
# 17    w-XO4XiRop0
# 18    pK2zYHWDZKo
# 19    bT8qmoCgxZg
# 20    sGbxmsDFVnE
# 21    vn9mMeWcgoM
# 22    tmeOjFno6Do
# 23    seMwpP0yeu4
# 24    Skpu5HaVkOc
# 25    eisKxhjBnZ0
# 26    n-7K_OjsDCQ
# 27    ej3ioOneTy8
# 28    LfR8Su4ulX0
# 29    7GqClqvlObY
# 30    frdj1zb9sMY
# 31    0tkLUap7oGQ
# 32    dKrVegVI0Us
# 33    UZ4WBlveGfw
# 34    5mkm22yO-bs
# 35    D86RtevtfrA
# 36    yCOPJi0Urq4
# 37    bha24P9uw-E
# 38    mMb-RrhTxIE
# 39    9qPgK_u4vX8
# 40    Q0CbN8sfihY
# 41    OvW_L8sTu5E
# 42    VSB4wGIdDwo
# 43    2QKg5SZ_35I
# 44    pr7tDrwQ3t8
# 45    n9DwoQ7HWvI
# 46    FnCdOQsX5kc
# 47    ue80QwXMRHg
# 48    6DBi41reeF0
# 49    r9-DM9uBtVI
# ...

# %%
'''base_url_video = "https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id=Q0CbN8sfihY&key={}"

base_url = "https://www.googleapis.com/youtube/v3/videos"
params = {
    "part": "snippet,contentDetails,statistics",
    "id": video_id,
    "key": key
    
}
stats = requests.get(base_url, params=params).json()
pprint(stats)'''
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/wKwDKEYD_TuopgQa5rfPZtY4sb0"',
#  'items': [{'contentDetails': {'caption': 'true',
#                                'definition': 'hd',
#                                'dimension': '2d',
#                                'duration': 'PT2M35S',
#                                'licensedContent': True,
#                                'projection': 'rectangular'},
#             'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/bOv4NbzWQgsFCbfCVCNKVKAZh18"',
#             'id': 'Q0CbN8sfihY',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '24',
#                         'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'defaultAudioLanguage': 'en',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
# ...

# %%
for index, row in df_movies.iterrows():
    base_url_video = "https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id={}&key={}"
    video_id = row['Video ID']
    stats = requests.get(base_url_search.format(video_id,key))
    df_movies.set_value(index,"View Count", stats['items'][0]['statistics']['viewCount'])
    df_movies.set_value(index,"Video Title", stats['items'][0]['snippet']['title'])
    df_movies.set_value(index,"Like Count", stats['items'][0]['statistics']['likeCount'])
    df_movies.set_value(index,"Dislike Count", stats['items'][0]['statistics']['dislikeCount'])
    df_movies.set_value(index,"Comment Count", stats['items'][0]['statistics']['commentCount'])

df_movies
# Out:
# https://www.googleapis.com/youtube/v3/search?part=snippet&q=movie%2Btrailer%2BEAzGXqJSDJ8&key=AIzaSyDJjB7jRXjdsPFeMeOJOm62lf_yk27GmY0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-182a5ce77244> in <module>()
#       4     stats = requests.get(base_url_search.format(video_id,key))
#       5     print(stats.url)
# ----> 6     df_movies.set_value(index,"View Count", stats['items'][0]['statistics']['viewCount'])
#       7     df_movies.set_value(index,"Video Title", stats['items'][0]['snippet']['title'])
#       8     df_movies.set_value(index,"Like Count", stats['items'][0]['statistics']['likeCount'])
#
# TypeError: 'Response' object is not subscriptable

# %%
base_url_video = "https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id={}&key={}"
id = "Q0CbN8sfihY"

test2 = requests.get(base_url_video.format(id,key)).json()
pprint(test2)
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/h3Y_DGPUebyuiPYuLoZBPaYf9nw"',
#  'items': [{'contentDetails': {'caption': 'true',
#                                'definition': 'hd',
#                                'dimension': '2d',
#                                'duration': 'PT2M35S',
#                                'licensedContent': True,
#                                'projection': 'rectangular'},
#             'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/xH5j0qnSFXHuJ90TqRCEB6CSmbQ"',
#             'id': 'Q0CbN8sfihY',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '24',
#                         'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'defaultAudioLanguage': 'en',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
# ...

# %%
stats = requests.get("https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id=Q0CbN8sfihY&key=AIzaSyDJjB7jRXjdsPFeMeOJOm62lf_yk27GmY0").json()

pprint(stats)
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/O5t1nq3Dwuy62rhwhXZuf73mo-o"',
#  'items': [{'contentDetails': {'caption': 'true',
#                                'definition': 'hd',
#                                'dimension': '2d',
#                                'duration': 'PT2M35S',
#                                'licensedContent': True,
#                                'projection': 'rectangular'},
#             'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/jHTpYMlCwNjMAx-Sh1XJlkHfMcg"',
#             'id': 'Q0CbN8sfihY',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '24',
#                         'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'defaultAudioLanguage': 'en',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
# ...

# %%
view_count = stats['items'][0]['statistics']['viewCount']
print(view_count)
# Out:
# 50020211

# %%
video_title = stats['items'][0]['snippet']['title']
print(video_title)
# Out:
# Star Wars: The Last Jedi Trailer (Official)
