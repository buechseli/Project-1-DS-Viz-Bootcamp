# %%
import json
import requests
from pprint import pprint

# %%
base_url_search = "https://www.googleapis.com/youtube/v3/search?part=snippet&q=movie%2Btrailer%2B{}&key={}"
q = "thelastjedi"
key = "AIzaSyDJjB7jRXjdsPFeMeOJOm62lf_yk27GmY0"

test = requests.get(base_url_search.format(q,key)).json()
pprint(test)
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/ar71BwlSRkdRg9FHhr-qHHbDB2k"',
#  'items': [{'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/1tTqLOdlVxv9M_QI-SdGjAJdafM"',
#             'id': {'kind': 'youtube#video', 'videoId': 'Q0CbN8sfihY'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
#                                        'December 15. Get your tickets now: '
#                                        'http://www.fandango.com/lastjedi Visit '
#                                        'Star Wars at http://www.starwars.com '
#                                        'Subscribe...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2017-10-10T01:58:59.000Z',
# ...

# %%
data = requests.get("https://www.googleapis.com/youtube/v3/search?part=snippet&q=movie%2Btrailer%2Bthelastjedi&key=AIzaSyDJjB7jRXjdsPFeMeOJOm62lf_yk27GmY0").json()

pprint(data)
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/m6XT--1F43TS2gekrWIQPecbjaY"',
#  'items': [{'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/1tTqLOdlVxv9M_QI-SdGjAJdafM"',
#             'id': {'kind': 'youtube#video', 'videoId': 'Q0CbN8sfihY'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
#                                        'December 15. Get your tickets now: '
#                                        'http://www.fandango.com/lastjedi Visit '
#                                        'Star Wars at http://www.starwars.com '
#                                        'Subscribe...',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2017-10-10T01:58:59.000Z',
# ...

# %%
data.keys()
video_id = data['items'][0]['id']['videoId']
print(video_id)
# Out:
# Q0CbN8sfihY

# %%
base_url_video = "https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id={}&key={}"
id = "Q0CbN8sfihY"

test2 = requests.get(base_url_video.format(id,key)).json()
pprint(test2)
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/h3Y_DGPUebyuiPYuLoZBPaYf9nw"',
#  'items': [{'contentDetails': {'caption': 'true',
#                                'definition': 'hd',
#                                'dimension': '2d',
#                                'duration': 'PT2M35S',
#                                'licensedContent': True,
#                                'projection': 'rectangular'},
#             'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/xH5j0qnSFXHuJ90TqRCEB6CSmbQ"',
#             'id': 'Q0CbN8sfihY',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '24',
#                         'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'defaultAudioLanguage': 'en',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
# ...

# %%
stats = requests.get("https://www.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id=Q0CbN8sfihY&key=AIzaSyDJjB7jRXjdsPFeMeOJOm62lf_yk27GmY0").json()

pprint(stats)
# Out:
# {'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/FO5xSSOG1paMGtuNPKNCizbkGrs"',
#  'items': [{'contentDetails': {'caption': 'true',
#                                'definition': 'hd',
#                                'dimension': '2d',
#                                'duration': 'PT2M35S',
#                                'licensedContent': True,
#                                'projection': 'rectangular'},
#             'etag': '"RmznBCICv9YtgWaaa_nWDIH1_GM/eGoEKodWd6dPGxGnFBRIMgdC978"',
#             'id': 'Q0CbN8sfihY',
#             'kind': 'youtube#video',
#             'snippet': {'categoryId': '24',
#                         'channelId': 'UCZGYJFUizSax-yElQaFDp5Q',
#                         'channelTitle': 'Star Wars',
#                         'defaultAudioLanguage': 'en',
#                         'description': 'Watch the new trailer for Star Wars: '
#                                        'The Last Jedi and see it in theaters '
# ...

# %%
view_count = stats['items'][0]['statistics']['viewCount']
print(view_count)
# Out:
# 50019897
