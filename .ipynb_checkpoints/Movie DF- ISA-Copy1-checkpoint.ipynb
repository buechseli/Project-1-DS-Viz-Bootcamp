# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
from pandas import Series

# %%
url = "http://www.omdbapi.com/?apikey=trilogy&t="

# %%
movies_df = pd.read_csv("2013-2017 Box Office Data.csv")
movies_df = movies_df.reset_index(level=None, drop = False, inplace = False, col_level = 0, col_fill = "")
s = pd.DataFrame(movies_df["Movie Title"])

# %%
s1 = s.reset_index(level=None, drop = False, inplace = False, col_level = 0, col_fill = "")

# %%
s1 = s.reset_index(level=None, drop = False, inplace = False, col_level = 0, col_fill = "")

# %%
s2 = s1["Movie Title"].str.split("(").apply(Series, 1)

# %%
s3 = s2.reset_index(level=None, drop = False, inplace = False, col_level = 0, col_fill = "")

# %%
movies_merge = movies_df.merge(s3, how='inner', on="index", left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False)
movies_merge
del movies_merge["Movie Title"]
del movies_merge[1]
del movies_merge["index"]
del movies_merge["Theaters.1"]
movies_merge = movies_merge.rename(columns = {0:"Movie Title"})
movies_merge.head()
movies_df = movies_merge[["Movie Title", "Year", "Studio","Total Gross","Theaters", "Opening", "Open", "Close"]]
movies_df
# Out:
#                                   Movie Title  Year   Studio    Total Gross  \
# 0             The Hunger Games: Catching Fire  2013      LGF  $424,668,047
# 1                                  Iron Man 3  2013       BV  $409,013,994
# 2                                      Frozen  2013       BV  $400,738,009
# 3                             Despicable Me 2  2013     Uni.  $368,061,265
# 4                                Man of Steel  2013       WB  $291,045,518
# 5                                     Gravity  2013       WB  $274,092,705
# 6                         Monsters University  2013       BV  $268,492,764
# 7         The Hobbit: The Desolation of Smaug  2013  WB (NL)  $258,366,855
# 8                            Fast & Furious 6  2013     Uni.  $238,679,850
# 9                   Oz The Great and Powerful  2013       BV  $234,911,825
# 10                            American Sniper  2014       WB  $350,126,372
# 11      The Hunger Games: Mockingjay - Part 1  2014      LGF  $337,135,885
# 12                    Guardians of the Galaxy  2014       BV  $333,176,600
# 13        Captain America: The Winter Soldier  2014       BV  $259,766,572
# 14                             The LEGO Movie  2014       WB  $257,760,692
# 15  The Hobbit: The Battle of the Five Armies  2014  WB (NL)  $255,119,788
# 16            Transformers: Age of Extinction  2014     Par.  $245,439,076
# 17                                 Maleficent  2014       BV  $241,410,378
# 18                 X-Men: Days of Future Past  2014      Fox  $233,921,534
# 19                                 Big Hero 6  2014       BV  $222,527,828
# 20               Star Wars: The Force Awakens  2015       BV  $936,662,225
# 21                             Jurassic World  2015     Uni.  $652,270,625
# 22                    Avengers: Age of Ultron  2015       BV  $459,005,868
# 23                                 Inside Out  2015       BV  $356,461,711
# 24                                  Furious 7  2015     Uni.  $353,007,020
# 25                                    Minions  2015     Uni.  $336,045,770
# 26      The Hunger Games: Mockingjay - Part 2  2015      LGF  $281,723,902
# 27                                The Martian  2015      Fox  $228,433,663
# 28                                Cinderella   2015       BV  $201,151,353
# 29                                    Spectre  2015     Sony  $200,074,609
# 30               Rogue One: A Star Wars Story  2016       BV      532177324
# 31                               Finding Dory  2016       BV      486295561
# 32                 Captain America: Civil War  2016       BV      408084349
# 33                    The Secret Life of Pets  2016     Uni.      368384330
# 34                           The Jungle Book   2016       BV      364001123
# 35                                   Deadpool  2016      Fox      363070709
# 36                                   Zootopia  2016       BV      341268248
# 37         Batman v Superman: Dawn of Justice  2016       WB      330360194
# 38                              Suicide Squad  2016       WB      325100054
# 39                                       Sing  2016     Uni.      270395425
# 40                   Star Wars: The Last Jedi  2017       BV  $620,164,565
# 41                      Beauty and the Beast   2017       BV  $504,014,165
# 42                               Wonder Woman  2017       WB  $412,563,408
# 43             Jumanji: Welcome to the Jungle  2017     Sony  $403,652,109
# 44             Guardians of the Galaxy Vol. 2  2017       BV  $389,813,101
# 45                     Spider-Man: Homecoming  2017     Sony  $334,201,140
# 46                                         It  2017  WB (NL)  $327,481,748
# 47                             Thor: Ragnarok  2017       BV  $315,058,289
# 48                            Despicable Me 3  2017     Uni.  $264,624,300
# 49                             Justice League  2017       WB  $229,024,295
#
#    Theaters        Opening    Open   Close
# 0     4,163  $158,074,286   22-Nov   3-Apr
# 1     4,253  $174,144,585    3-May  12-Sep
# 2     3,742      $243,390   22-Nov  17-Jul
# 3     4,003   $83,517,315    3-Jul  16-Jan
# 4     4,207  $116,619,362   14-Jun  19-Sep
# 5     3,820   $55,785,112    4-Oct   8-May
# 6     4,004   $82,429,469   21-Jun  19-Dec
# 7     3,928   $73,645,197   13-Dec  17-Apr
# 8     3,771   $97,375,245   24-May   5-Sep
# 9     3,912   $79,110,453    8-Mar  18-Jul
# 10    3,885      $633,456   25-Dec  25-Jun
# 11    4,151  $121,897,634   21-Nov  19-Mar
# 12    4,088   $94,320,883    1-Aug  22-Jan
# 13    3,938   $95,023,721    4-Apr  21-Aug
# 14    3,890   $69,050,279    7-Feb   4-Sep
# 15    3,875   $54,724,334   17-Dec   2-Apr
# 16    4,233  $100,038,390   27-Jun   9-Oct
# 17    3,948   $69,431,298   30-May   4-Dec
# 18    4,001   $90,823,660   23-May   9-Oct
# 19    3,773   $56,215,889    7-Nov  28-May
# 20    4,134  $247,966,675   18-Dec   2-Jun
# 21    4,291  $208,806,270   12-Jun  19-Nov
# 22    4,276  $191,271,109    1-May   8-Oct
# 23    4,158   $90,440,272   19-Jun  10-Dec
# 24    4,022  $147,187,040    3-Apr  24-Jul
# 25    4,311  $115,718,405   10-Jul  17-Dec
# 26    4,175  $102,665,981   20-Nov  25-Feb
# 27    3,854   $54,308,575    2-Oct  17-Mar
# 28    3,848   $67,877,361   13-Mar  17-Sep
# 29    3,929   $70,403,148    6-Nov   7-Apr
# 30     4157      155081681   43450   43224
# 31     4305      135060273   43268   43442
# 32     4226      179139142   43226   43365
# 33     4381      104352905   43289   43463
# 34     4144      103261464   43205   43372
# 35     3856      132434639   43143   43267
# 36     3959       75063401   43163   43316
# 37     4256      166007347   43184   43267
# 38     4255      133682248   43317   43414
# 39     4029       35258145   43455   43221
# 40    4,232  $220,009,584   15-Dec       -
# 41    4,210  $174,750,616   17-Mar  13-Jul
# 42    4,165  $103,251,471    2-Jun   9-Nov
# 43    3,849   $36,169,328   20-Dec       -
# 44    4,347  $146,510,104    5-May  21-Sep
# 45    4,348  $117,027,503    7-Jul  30-Nov
# 46    4,148  $123,403,419    8-Sep  14-Dec
# 47    4,080  $122,744,989    3-Nov  15-Mar
# 48    4,535   $72,434,025   30-Jun  21-Dec
# 49    4,051   $93,842,239   17-Nov  15-Mar

# %%
movies_df["Rated"] = ""
movies_df["Runtime"]= ""
movies_df["Director"]=""
movies_df["Actor 1"] = ""
movies_df["Actor 2"] = ""
movies_df["Rotten Tomatoes"] = ""
movies_df["Metacritic"] = ""
movies_df["IMDB Rating"] = ""
movies_df["Production Studio"] =""
movies_df.head()
# Out:
#                        Movie Title  Year Studio    Total Gross Theaters  \
# 0  The Hunger Games: Catching Fire  2013    LGF  $424,668,047     4,163
# 1                       Iron Man 3  2013     BV  $409,013,994     4,253
# 2                           Frozen  2013     BV  $400,738,009     3,742
# 3                  Despicable Me 2  2013   Uni.  $368,061,265     4,003
# 4                     Man of Steel  2013     WB  $291,045,518     4,207
#
#          Opening    Open   Close Rated Runtime Director Actor 1 Actor 2  \
# 0  $158,074,286   22-Nov   3-Apr
# 1  $174,144,585    3-May  12-Sep
# 2      $243,390   22-Nov  17-Jul
# 3   $83,517,315    3-Jul  16-Jan
# 4  $116,619,362   14-Jun  19-Sep
#
#   Rotten Tomatoes Metacritic IMDB Rating Production Studio
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in movies_df.iterrows():
    base_url = "http://www.omdbapi.com/?apikey=trilogy"
    params = {
        "t": row["Movie Title"],
        "y": row["Year"]
    }

    # make request and print url
    response = requests.get(base_url, params=params).json()
    
    
    try:
        movies_df.set_value(index, "Rated", response["Rated"])
        movies_df.set_value(index, "Runtime", response["Runtime"])
        movies_df.set_value(index, "Director", response["Director"])
        movies_df.set_value(index, "Actor 1", response["Actors"])
        movies_df.set_value(index, "Actor 2", response["Actors"])
        movies_df.set_value(index, "Rotten Tomatoes", response["Ratings"][1]["Value"])
        movies_df.set_value(index, "Metacritic", response["Ratings"][2]["Value"])
        movies_df.set_value(index, "IMDB Rating", response["Ratings"][0]["Value"])
        movies_df.set_value(index, "Production Studio", response["Production"])
            
        
    except (KeyError, IndexError):
        print(f" {movie} Missing field/result... skipping.")

# %%
movies_df
# Out:
#                                   Movie Title  Year   Studio    Total Gross  \
# 0             The Hunger Games: Catching Fire  2013      LGF  $424,668,047
# 1                                  Iron Man 3  2013       BV  $409,013,994
# 2                                      Frozen  2013       BV  $400,738,009
# 3                             Despicable Me 2  2013     Uni.  $368,061,265
# 4                                Man of Steel  2013       WB  $291,045,518
# 5                                     Gravity  2013       WB  $274,092,705
# 6                         Monsters University  2013       BV  $268,492,764
# 7         The Hobbit: The Desolation of Smaug  2013  WB (NL)  $258,366,855
# 8                            Fast & Furious 6  2013     Uni.  $238,679,850
# 9                   Oz The Great and Powerful  2013       BV  $234,911,825
# 10                            American Sniper  2014       WB  $350,126,372
# 11      The Hunger Games: Mockingjay - Part 1  2014      LGF  $337,135,885
# 12                    Guardians of the Galaxy  2014       BV  $333,176,600
# 13        Captain America: The Winter Soldier  2014       BV  $259,766,572
# 14                             The LEGO Movie  2014       WB  $257,760,692
# 15  The Hobbit: The Battle of the Five Armies  2014  WB (NL)  $255,119,788
# 16            Transformers: Age of Extinction  2014     Par.  $245,439,076
# 17                                 Maleficent  2014       BV  $241,410,378
# 18                 X-Men: Days of Future Past  2014      Fox  $233,921,534
# 19                                 Big Hero 6  2014       BV  $222,527,828
# 20               Star Wars: The Force Awakens  2015       BV  $936,662,225
# 21                             Jurassic World  2015     Uni.  $652,270,625
# 22                    Avengers: Age of Ultron  2015       BV  $459,005,868
# 23                                 Inside Out  2015       BV  $356,461,711
# 24                                  Furious 7  2015     Uni.  $353,007,020
# 25                                    Minions  2015     Uni.  $336,045,770
# 26      The Hunger Games: Mockingjay - Part 2  2015      LGF  $281,723,902
# 27                                The Martian  2015      Fox  $228,433,663
# 28                                Cinderella   2015       BV  $201,151,353
# 29                                    Spectre  2015     Sony  $200,074,609
# 30               Rogue One: A Star Wars Story  2016       BV      532177324
# 31                               Finding Dory  2016       BV      486295561
# 32                 Captain America: Civil War  2016       BV      408084349
# 33                    The Secret Life of Pets  2016     Uni.      368384330
# 34                           The Jungle Book   2016       BV      364001123
# 35                                   Deadpool  2016      Fox      363070709
# 36                                   Zootopia  2016       BV      341268248
# 37         Batman v Superman: Dawn of Justice  2016       WB      330360194
# 38                              Suicide Squad  2016       WB      325100054
# 39                                       Sing  2016     Uni.      270395425
# 40                   Star Wars: The Last Jedi  2017       BV  $620,164,565
# 41                      Beauty and the Beast   2017       BV  $504,014,165
# 42                               Wonder Woman  2017       WB  $412,563,408
# 43             Jumanji: Welcome to the Jungle  2017     Sony  $403,652,109
# 44             Guardians of the Galaxy Vol. 2  2017       BV  $389,813,101
# 45                     Spider-Man: Homecoming  2017     Sony  $334,201,140
# 46                                         It  2017  WB (NL)  $327,481,748
# 47                             Thor: Ragnarok  2017       BV  $315,058,289
# 48                            Despicable Me 3  2017     Uni.  $264,624,300
# 49                             Justice League  2017       WB  $229,024,295
#
#    Theaters        Opening    Open   Close  Rated  Runtime  \
# 0     4,163  $158,074,286   22-Nov   3-Apr  PG-13  146 min
# 1     4,253  $174,144,585    3-May  12-Sep  PG-13  130 min
# 2     3,742      $243,390   22-Nov  17-Jul     PG  102 min
# 3     4,003   $83,517,315    3-Jul  16-Jan     PG   98 min
# 4     4,207  $116,619,362   14-Jun  19-Sep  PG-13  143 min
# 5     3,820   $55,785,112    4-Oct   8-May  PG-13   91 min
# 6     4,004   $82,429,469   21-Jun  19-Dec      G  104 min
# 7     3,928   $73,645,197   13-Dec  17-Apr  PG-13  161 min
# 8     3,771   $97,375,245   24-May   5-Sep  PG-13  130 min
# 9     3,912   $79,110,453    8-Mar  18-Jul     PG  130 min
# 10    3,885      $633,456   25-Dec  25-Jun      R  133 min
# 11    4,151  $121,897,634   21-Nov  19-Mar  PG-13  123 min
# 12    4,088   $94,320,883    1-Aug  22-Jan  PG-13  121 min
# 13    3,938   $95,023,721    4-Apr  21-Aug  PG-13  136 min
# 14    3,890   $69,050,279    7-Feb   4-Sep     PG  100 min
# 15    3,875   $54,724,334   17-Dec   2-Apr  PG-13  144 min
# 16    4,233  $100,038,390   27-Jun   9-Oct  PG-13  165 min
# 17    3,948   $69,431,298   30-May   4-Dec     PG   97 min
# 18    4,001   $90,823,660   23-May   9-Oct  PG-13  132 min
# 19    3,773   $56,215,889    7-Nov  28-May     PG  102 min
# 20    4,134  $247,966,675   18-Dec   2-Jun  PG-13  136 min
# 21    4,291  $208,806,270   12-Jun  19-Nov  PG-13  124 min
# 22    4,276  $191,271,109    1-May   8-Oct  PG-13  141 min
# 23    4,158   $90,440,272   19-Jun  10-Dec     PG   95 min
# 24    4,022  $147,187,040    3-Apr  24-Jul  PG-13  137 min
# 25    4,311  $115,718,405   10-Jul  17-Dec     PG   91 min
# 26    4,175  $102,665,981   20-Nov  25-Feb  PG-13  137 min
# 27    3,854   $54,308,575    2-Oct  17-Mar  PG-13  144 min
# 28    3,848   $67,877,361   13-Mar  17-Sep     PG  105 min
# 29    3,929   $70,403,148    6-Nov   7-Apr  PG-13  148 min
# 30     4157      155081681   43450   43224  PG-13  133 min
# 31     4305      135060273   43268   43442     PG   97 min
# 32     4226      179139142   43226   43365  PG-13  147 min
# 33     4381      104352905   43289   43463     PG   87 min
# 34     4144      103261464   43205   43372     PG  106 min
# 35     3856      132434639   43143   43267      R  108 min
# 36     3959       75063401   43163   43316     PG  108 min
# 37     4256      166007347   43184   43267  PG-13  151 min
# 38     4255      133682248   43317   43414  PG-13  123 min
# 39     4029       35258145   43455   43221     PG  108 min
# 40    4,232  $220,009,584   15-Dec       -  PG-13  152 min
# 41    4,210  $174,750,616   17-Mar  13-Jul     PG  129 min
# 42    4,165  $103,251,471    2-Jun   9-Nov  PG-13  141 min
# 43    3,849   $36,169,328   20-Dec       -  PG-13  119 min
# 44    4,347  $146,510,104    5-May  21-Sep  PG-13  136 min
# 45    4,348  $117,027,503    7-Jul  30-Nov  PG-13  133 min
# 46    4,148  $123,403,419    8-Sep  14-Dec      R  135 min
# 47    4,080  $122,744,989    3-Nov  15-Mar  PG-13  130 min
# 48    4,535   $72,434,025   30-Jun  21-Dec     PG   89 min
# 49    4,051   $93,842,239   17-Nov  15-Mar  PG-13  120 min
#
#                                              Director  \
# 0                                    Francis Lawrence
# 1                                         Shane Black
# 2                            Chris Buck, Jennifer Lee
# 3                         Pierre Coffin, Chris Renaud
# 4                                         Zack Snyder
# 5                                      Alfonso Cuarón
# 6                                         Dan Scanlon
# 7                                       Peter Jackson
# 8                                          Justin Lin
# 9                                           Sam Raimi
# 10                                     Clint Eastwood
# 11                                   Francis Lawrence
# 12                                         James Gunn
# 13                           Anthony Russo, Joe Russo
# 14                      Phil Lord, Christopher Miller
# 15                                      Peter Jackson
# 16                                        Michael Bay
# 17                                   Robert Stromberg
# 18                                       Bryan Singer
# 19                           Don Hall, Chris Williams
# 20                                        J.J. Abrams
# 21                                    Colin Trevorrow
# 22                                        Joss Whedon
# 23        Pete Docter, Ronnie Del Carmen(co-director)
# 24                                          James Wan
# 25                          Kyle Balda, Pierre Coffin
# 26                                   Francis Lawrence
# 27                                       Ridley Scott
# 28                                    Kenneth Branagh
# 29                                         Sam Mendes
# 30                                     Gareth Edwards
# 31         Andrew Stanton, Angus MacLane(co-director)
# 30  Felicity Jones, Diego Luna, Alan Tudyk, Donnie...             85%
# 31  Ellen DeGeneres, Albert Brooks, Ed O'Neill, Ka...             94%
# 32  Chris Evans, Robert Downey Jr., Scarlett Johan...             91%
# 33  Louis C.K., Eric Stonestreet, Kevin Hart, Jenn...             75%
# 34  Neel Sethi, Bill Murray, Ben Kingsley, Idris Elba             95%
# 35  Ryan Reynolds, Karan Soni, Ed Skrein, Michael ...             83%
# 36  Ginnifer Goodwin, Jason Bateman, Idris Elba, J...             98%
# 37  Ben Affleck, Henry Cavill, Amy Adams, Jesse Ei...             27%
# 38  Will Smith, Jaime FitzSimons, Ike Barinholtz, ...             26%
# 39  Matthew McConaughey, Reese Witherspoon, Seth M...             73%
# 40  Mark Hamill, Carrie Fisher, Adam Driver, Daisy...             91%
# 41     Emma Watson, Dan Stevens, Luke Evans, Josh Gad             71%
# 42  Gal Gadot, Chris Pine, Connie Nielsen, Robin W...             92%
# 43  Dwayne Johnson, Kevin Hart, Jack Black, Karen ...             76%
# 44  Chris Pratt, Zoe Saldana, Dave Bautista, Vin D...             83%
# 45  Tom Holland, Michael Keaton, Robert Downey Jr....             92%
# 46  Jaeden Lieberher, Jeremy Ray Taylor, Sophia Li...             85%
# 47  Chris Hemsworth, Tom Hiddleston, Cate Blanchet...             92%
# 48  Steve Carell, Kristen Wiig, Trey Parker, Miran...             60%
# 49    Ben Affleck, Henry Cavill, Amy Adams, Gal Gadot             40%
#
#    Metacritic IMDB Rating              Production Studio
# 0      76/100      7.5/10                Lionsgate Films
# 1      62/100      7.2/10           Walt Disney Pictures
# 2      74/100      7.5/10           Walt Disney Pictures
# 3      62/100      7.4/10             Universal Pictures
# 4      55/100      7.1/10          Warner Bros. Pictures
# 5      96/100      7.8/10          Warner Bros. Pictures
# 6      65/100      7.3/10           Walt Disney Pictures
# 7      66/100      7.9/10                   Warner Bros.
# 8      61/100      7.1/10             Universal Pictures
# 9      44/100      6.3/10           Walt Disney Pictures
# 10     72/100      7.3/10                   Warner Bros.
# 11     64/100      6.7/10                Lionsgate Films
# 12     76/100      8.1/10           Walt Disney Pictures
# 13     70/100      7.8/10           Walt Disney Pictures
# 14     83/100      7.8/10          Warner Bros. Pictures
# 15     59/100      7.4/10                   Warner Bros.
# 16     32/100      5.7/10             Paramount Pictures
# 17     56/100      7.0/10           Walt Disney Pictures
# 18     74/100      8.0/10               20th Century Fox
# 19     74/100      7.8/10           Walt Disney Pictures
# 20     81/100      8.0/10           Walt Disney Pictures
# 21     59/100      7.0/10             Universal Pictures
# 22     66/100      7.4/10           Walt Disney Pictures
# 23     94/100      8.2/10                   Disney/Pixar
# 24     67/100      7.2/10             Universal Pictures
# 25     56/100      6.4/10             Universal Pictures
# 26     65/100      6.5/10                Lionsgate Films
# 27     80/100      8.0/10               20th Century Fox
# 28     67/100      6.9/10           Walt Disney Pictures
# 29     60/100      6.8/10                  Sony Pictures
# 30     65/100      7.8/10           Walt Disney Pictures
# 31     77/100      7.4/10     Walt Disney Pictures/PIXAR
# 32     75/100      7.8/10           Walt Disney Pictures
# 33     61/100      6.5/10             Universal Pictures
# 34     77/100      7.5/10           Walt Disney Pictures
# 35     65/100      8.0/10               20th Century Fox
# 36     78/100      8.0/10  Walt Disney Animation Studios
# 37     44/100      6.6/10          Warner Bros. Pictures
# 38     40/100      6.1/10          Warner Bros. Pictures
# 39     59/100      7.1/10     Illumination Entertainment
# 40     85/100      7.4/10           Walt Disney Pictures
# 41     65/100      7.3/10           Walt Disney Pictures
# 42     76/100      7.5/10          Warner Bros. Pictures
# 43     58/100      7.0/10              Columbia Pictures
# 44     67/100      7.7/10           Walt Disney Pictures
# 45     73/100      7.5/10                  Sony Pictures
# 46     69/100      7.5/10          Warner Bros. Pictures
# 47     74/100      8.0/10           Walt Disney Pictures
# 48     49/100      6.3/10             Universal Pictures
# 49     45/100      6.8/10          Warner Bros. Pictures

# %%
movies_df.dtypes
# Out:
# Movie Title          object
# Year                  int64
# Studio               object
# Total Gross          object
# Theaters             object
# Opening              object
# Open                 object
# Close                object
# Rated                object
# Runtime              object
# Director             object
# Actor 1              object
# Actor 2              object
# Rotten Tomatoes      object
# Metacritic           object
# IMDB Rating          object
# Production Studio    object
# dtype: object

# %%
new_data = movies_df['Total Gross'].str.replace('$','')
new_data
# Out:
# 0     424,668,047
# 1     409,013,994
# 2     400,738,009
# 3     368,061,265
# 4     291,045,518
# 5     274,092,705
# 6     268,492,764
# 7     258,366,855
# 8     238,679,850
# 9     234,911,825
# 10    350,126,372
# 11    337,135,885
# 12    333,176,600
# 13    259,766,572
# 14    257,760,692
# 15    255,119,788
# 16    245,439,076
# 17    241,410,378
# 18    233,921,534
# 19    222,527,828
# 20    936,662,225
# 21    652,270,625
# 22    459,005,868
# 23    356,461,711
# 24    353,007,020
# 25    336,045,770
# 26    281,723,902
# 27    228,433,663
# 28    201,151,353
# 29    200,074,609
# 30       532177324
# 31       486295561
# 32       408084349
# 33       368384330
# 34       364001123
# 35       363070709
# 36       341268248
# 37       330360194
# 38       325100054
# 39       270395425
# 40    620,164,565
# 41    504,014,165
# 42    412,563,408
# 43    403,652,109
# 44    389,813,101
# 45    334,201,140
# 46    327,481,748
# 47    315,058,289
# 48    264,624,300
# 49    229,024,295
# Name: Total Gross, dtype: object

# %%
movies_df['Total Gross'] = pd.to_numeric(movies_df['Total Gross'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-79e10912f95a> in <module>()
# ----> 1 movies_df['Total Gross'] = pd.to_numeric(movies_df['Total Gross'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Total Gross'

# %%
movies_df['Total Gross'] = gender_data["Average Purchase Price"].map("{:,.2f}".format)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-42e0ce5c9dd1> in <module>()
# ----> 1 movies_df['Total Gross'] = movies_df['Total Gross'].map("{:,.2f}".format)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ValueError: Unknown format code 'f' for object of type 'str'
